# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv("data.csv", sep=";")
df

# %%
df2 = df.melt(id_vars=["H03", "H05", "H16"],
              var_name="Date", value_name="sales")

# %%
df2[["Prefix", "Month", "Year"]] = df2["Date"].astype(
    "str").str.extract(r'(MO)(\d{2})(\d{4})')

# %%
df2
# Out:
#            H03                          H05             H16      Date  sales
# 0     FMP20000         Total, gold included  Actual indices  MO011980  102.9  \
# 1     FMP20001         Total, gold excluded  Actual indices  MO011980   55.1
# 2     FMP21000                         Coal  Actual indices  MO011980   44.7
# 3     FMP23010                     Iron ore  Actual indices  MO011980   37.8
# 4     FMP23020                     Chromium  Actual indices  MO011980   24.7
# ...        ...                          ...             ...       ...    ...
# 3859  FMP23999      Other metallic minerals  Actual indices  MO122002  140.4
# 3860  FMP24000                         Gold  Actual indices  MO122002  282.8
# 3861  FMP27000                     Diamonds  Actual indices  MO122002  128.8
# 3862  FMP28888           Building materials  Actual indices  MO122002   59.8
# 3863  FMP28999  Other non-metallic minerals  Actual indices  MO122002  161.7
#
#      Prefix Month  Year
# 0        MO    01  1980
# 1        MO    01  1980
# 2        MO    01  1980
# 3        MO    01  1980
# 4        MO    01  1980
# ...     ...   ...   ...
# 3859     MO    12  2002
# 3860     MO    12  2002
# 3861     MO    12  2002
# 3862     MO    12  2002
# 3863     MO    12  2002
#
# [3864 rows x 8 columns]

# %%
df2["date"] = pd.to_datetime(df2["Year"].astype(
    str)+"-"+df2["Month"].astype(str)+"-"+"01", format="%Y-%m-%d")

# %%
df2
# Out:
#            H03                          H05             H16      Date  sales
# 0     FMP20000         Total, gold included  Actual indices  MO011980  102.9  \
# 1     FMP20001         Total, gold excluded  Actual indices  MO011980   55.1
# 2     FMP21000                         Coal  Actual indices  MO011980   44.7
# 3     FMP23010                     Iron ore  Actual indices  MO011980   37.8
# 4     FMP23020                     Chromium  Actual indices  MO011980   24.7
# ...        ...                          ...             ...       ...    ...
# 3859  FMP23999      Other metallic minerals  Actual indices  MO122002  140.4
# 3860  FMP24000                         Gold  Actual indices  MO122002  282.8
# 3861  FMP27000                     Diamonds  Actual indices  MO122002  128.8
# 3862  FMP28888           Building materials  Actual indices  MO122002   59.8
# 3863  FMP28999  Other non-metallic minerals  Actual indices  MO122002  161.7
#
#      Prefix Month  Year       date
# 0        MO    01  1980 1980-01-01
# 1        MO    01  1980 1980-01-01
# 2        MO    01  1980 1980-01-01
# 3        MO    01  1980 1980-01-01
# 4        MO    01  1980 1980-01-01
# ...     ...   ...   ...        ...
# 3859     MO    12  2002 2002-12-01
# 3860     MO    12  2002 2002-12-01
# 3861     MO    12  2002 2002-12-01
# 3862     MO    12  2002 2002-12-01
# 3863     MO    12  2002 2002-12-01
#
# [3864 rows x 9 columns]

# %%
df2.drop(columns=["Date", "Prefix", "Month", "Year"], inplace=True)
df2
# Out:
#            H03                          H05             H16  sales       date
# 0     FMP20000         Total, gold included  Actual indices  102.9 1980-01-01
# 1     FMP20001         Total, gold excluded  Actual indices   55.1 1980-01-01
# 2     FMP21000                         Coal  Actual indices   44.7 1980-01-01
# 3     FMP23010                     Iron ore  Actual indices   37.8 1980-01-01
# 4     FMP23020                     Chromium  Actual indices   24.7 1980-01-01
# ...        ...                          ...             ...    ...        ...
# 3859  FMP23999      Other metallic minerals  Actual indices  140.4 2002-12-01
# 3860  FMP24000                         Gold  Actual indices  282.8 2002-12-01
# 3861  FMP27000                     Diamonds  Actual indices  128.8 2002-12-01
# 3862  FMP28888           Building materials  Actual indices   59.8 2002-12-01
# 3863  FMP28999  Other non-metallic minerals  Actual indices  161.7 2002-12-01
#
# [3864 rows x 5 columns]

# %%
df3 = pd.get_dummies(df2, columns=['date', 'H03', 'H05', 'H16'])
df3
# Out:
#       sales  date_1980-01-01 00:00:00  date_1980-02-01 00:00:00
# 0     102.9                      True                     False  \
# 1      55.1                      True                     False
# 2      44.7                      True                     False
# 3      37.8                      True                     False
# 4      24.7                      True                     False
# ...     ...                       ...                       ...
# 3859  140.4                     False                     False
# 3860  282.8                     False                     False
# 3861  128.8                     False                     False
# 3862   59.8                     False                     False
# 3863  161.7                     False                     False
#
#       date_1980-03-01 00:00:00  date_1980-04-01 00:00:00
# 0                        False                     False  \
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ...                        ...                       ...
# 3859                     False                     False
# 3860                     False                     False
# 3861                     False                     False
# 3862                     False                     False
# 3863                     False                     False
#
#       date_1980-05-01 00:00:00  date_1980-06-01 00:00:00
# 0                        False                     False  \
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ...                        ...                       ...
# 3859                     False                     False
# 3860                     False                     False
# 3861                     False                     False
# 3862                     False                     False
# 3863                     False                     False
#
#       date_1980-07-01 00:00:00  date_1980-08-01 00:00:00
# 0                        False                     False  \
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ...                        ...                       ...
# 3859                     False                     False
# 3860                     False                     False
# 3861                     False                     False
# 3862                     False                     False
# 3863                     False                     False
#
#       date_1980-09-01 00:00:00  ...  H05_Gold  H05_Iron ore
# 0                        False  ...     False         False  \
# 1                        False  ...     False         False
# 2                        False  ...     False         False
# 3                        False  ...     False          True
# 4                        False  ...     False         False
# ...                        ...  ...       ...           ...
# 3859                     False  ...     False         False
# 3860                     False  ...      True         False
# 3861                     False  ...     False         False
# 3862                     False  ...     False         False
# 3863                     False  ...     False         False
#
#       H05_Manganese ore  H05_Nickel  H05_Other metallic minerals
# 0                 False       False                        False  \
# 1                 False       False                        False
# 2                 False       False                        False
# 3                 False       False                        False
# 4                 False       False                        False
# ...                 ...         ...                          ...
# 3859              False       False                         True
# 3860              False       False                        False
# 3861              False       False                        False
# 3862              False       False                        False
# 3863              False       False                        False
#
#       H05_Other non-metallic minerals  H05_PGMs  H05_Total, gold excluded
# 0                               False     False                     False  \
# 1                               False     False                      True
# 2                               False     False                     False
# 3                               False     False                     False
# 4                               False     False                     False
# ...                               ...       ...                       ...
# 3859                            False     False                     False
# 3860                            False     False                     False
# 3861                            False     False                     False
# 3862                            False     False                     False
# 3863                             True     False                     False
#
#       H05_Total, gold included  H16_Actual indices
# 0                         True                True
# 1                        False                True
# 2                        False                True
# 3                        False                True
# 4                        False                True
# ...                        ...                 ...
# 3859                     False                True
# 3860                     False                True
# 3861                     False                True
# 3862                     False                True
# 3863                     False                True
#
# [3864 rows x 306 columns]

# %%
X = df3.drop('sales', axis=1)
y = df3['sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
degree = 2  
poly = PolynomialFeatures(degree)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
alpha = 1.0  
model = Ridge(alpha=alpha)
model.fit(X_train_poly, y_train)
# Out:
# c:\users\student\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23040/1130210217.py in <module>
#       1 alpha = 1.0
#       2 model = Ridge(alpha=alpha)
# ----> 3 model.fit(X_train_poly, y_train)
#
# c:\users\student\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#    1128             y_numeric=True,
#    1129         )
# -> 1130         return super().fit(X, y, sample_weight=sample_weight)
#    1131
#    1132
#
# c:\users\student\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#     887                 params = {}
#     888
# --> 889             self.coef_, self.n_iter_ = _ridge_regression(
#     890                 X,
#     891                 y,
#
# c:\users\student\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_ridge.py in _ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, positive, random_state, return_n_iter, return_intercept, X_scale, X_offset, check_input, fit_intercept)
#     689             K = safe_sparse_dot(X, X.T, dense_output=True)
#     690             try:
# --> 691                 dual_coef = _solve_cholesky_kernel(K, y, alpha)
#     692
#     693                 coef = safe_sparse_dot(X.T, dual_coef, dense_output=True).T
#
# c:\users\student\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_ridge.py in _solve_cholesky_kernel(K, y, alpha, sample_weight, copy)
#     247             #       use the fall-back solution below in case a LinAlgError
#     248             #       is raised
# --> 249             dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
#     250         except np.linalg.LinAlgError:
#     251             warnings.warn(
#
# TypeError: solve() got an unexpected keyword argument 'sym_pos'

# %%
y_pred = model.predict(X_test_poly)

# %%
r_squared = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# %%
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared:", r_squared)
# Out:
# Mean Absolute Error (MAE): 20.382353654592492
# Mean Squared Error (MSE): 806.6100995638947
# R-squared: 0.9217881518752121

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', lw=2)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values (Linear Regression)')
plt.savefig('actual_vs_predicted.png')
plt.close()

# %%
with open('results.txt', 'w') as f:
    f.write(f"R2 Score: {r_squared}\n")
    f.write(f"Mean Absolute Error (MAE): {mae}\n")
    f.write(f"Mean Squared Error (MSE): {mse}\n")

# %%
print("Cross-validation R2 Scores:", cv_scores)
# Out:
# Cross-validation R2 Scores: [0.92462638 0.913236   0.92580849 0.9231589  0.92478722]
